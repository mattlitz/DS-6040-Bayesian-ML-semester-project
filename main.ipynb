# %% [markdown]
# ## Quantifying risk in Federal government grant programs

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Read files into notebook

# %%
agency19 = pd.read_csv('data/allfac19/agency19.txt', delimiter='|')
agency19
# Out:
#        AUDITYEAR   DBKEY        EIN  AGENCY
# 0           2019  100000  730776899       0
# 1           2019  100001  730777705       0
# 2           2019  100003  730779703       0
# 3           2019  100010  730784599       0
# 4           2019  100014  730785251       0
# ...          ...     ...        ...     ...
# 41109       2019   99989  730772341       0
# 41110       2019   99990  730772528       0
# 41111       2019   99993  730774245      84
# 41112       2019   99994  730775109       0
# 41113       2019   99998  730776195       0
#
# [41114 rows x 4 columns]

# %%
gen19 = pd.read_csv('data/allfac19/gen19.txt',delimiter='|', encoding = 'latin')
gen19
# Out:
# C:\Users\mattl\AppData\Local\Temp/ipykernel_48648/525049496.py:1: DtypeWarning: Columns (64) have mixed types. Specify dtype option on import or set low_memory=False.
#   gen19 = pd.read_csv('data/allfac19/gen19.txt',delimiter='|',encoding = 'latin')
#        AUDITYEAR   DBKEY  TYPEOFENTITY  FYENDDATE AUDITTYPE PERIODCOVERED  \
# 0           2019  100000           908  30-SEP-19         S             A
# 1           2019  100001           908  31-OCT-19         S             A
# 2           2019  100003           908  30-APR-19         S             A
# 3           2019  100010           909  30-JUN-19         S             A
# 4           2019  100014           908  30-JUN-19         S             A
# ...          ...     ...           ...        ...       ...           ...
# 37031       2019   99989           908  31-MAR-19         S             A
# 37032       2019   99990           909  31-DEC-19         S             A
# 37033       2019   99993           904  30-JUN-19         S             A
# 37034       2019   99994           909  30-SEP-19         S             A
# 37035       2019   99998           908  30-SEP-19         S             A
#
#        NUMBERMONTHS        EIN MULTIPLEEINS  EINSUBCODE  ...  TOTFEDEXPEND  \
# 0               NaN  730776899            N         NaN  ...       2883811
# 1               NaN  730777705            N         NaN  ...      14017865
# 2               NaN  730779703            Y         NaN  ...       2510565
# 3               NaN  730784599            N         NaN  ...       2748608
# 4               NaN  730785251            N         NaN  ...       3185870
# ...             ...        ...          ...         ...  ...           ...
# 37031           NaN  730772341            N         NaN  ...       1108402
# 37032           NaN  730772528            N         NaN  ...       9886462
# 37033           NaN  730774245            N         NaN  ...       2638731
# 37034           NaN  730775109            N         NaN  ...       5937356
# 37035           NaN  730776195            N         NaN  ...       3593178
#
#       DATEFIREWALL PREVIOUSDATEFIREWALL REPORTREQUIRED  MULTIPLE_CPAS  \
# 0        03-APR-20                  NaN            NaN              N
# 1        01-JUL-20                  NaN            NaN              N
# 2        15-NOV-19                  NaN            NaN              N
# 3        29-JAN-20                  NaN            NaN              N
# 4        09-JAN-20                  NaN            NaN              N
# ...            ...                  ...            ...            ...
# 37031    24-JAN-20                  NaN            NaN              N
# 37032    30-SEP-20                  NaN            NaN              N
# 37033    09-JUN-21                  NaN            NaN              N
# 37034    27-DEC-20                  NaN            NaN              N
# 37035    05-MAY-20                  NaN            NaN              N
#
#       AUDITOR_EIN FACACCEPTEDDATE  CPAFOREIGN CPACOUNTRY  \
# 0       208209116       17-MAR-20         NaN         US
# 1       208209116       29-JUN-20         NaN         US
# 2       208209116       12-NOV-19         NaN         US
# 3       271494012       20-NOV-19         NaN         US
# 4       480573184       20-NOV-19         NaN         US
# ...           ...             ...         ...        ...
# 37031   271494012       20-NOV-19         NaN         US
# 37032   730604334       28-SEP-20         NaN         US
# 37033   845108762       04-JUN-21         NaN         US
# 37034   721351615       21-DEC-20         NaN         US
# 37035   208209116       02-APR-20         NaN         US
#
#                                  ENTITY_TYPE
# 0                                 Non-profit
# 1                                 Non-profit
# 2                                 Non-profit
# 3                           Local government
# 4                                 Non-profit
# ...                                      ...
# 37031                             Non-profit
# 37032                             Non-profit
# 37033  Institution of higher education (IHE)
# 37034                             Non-profit
# 37035                             Non-profit
#
# [37036 rows x 67 columns]

# %%
#received error message for bad data in a row - added "on_bad_lines='skip'""
cfda19 = pd.read_csv('data/allfac19/cfda19.txt',delimiter='|', encoding = 'latin',on_bad_lines='skip')
cfda19
# Out:
# C:\Users\mattl\AppData\Local\Temp/ipykernel_48648/3127143931.py:1: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   cfda19 = pd.read_csv('data/allfac19/cfda19.txt',delimiter='|', encoding = 'latin',on_bad_lines='skip')
#         AUDITYEAR   DBKEY        EIN    CFDA  \
# 0            2019  100248  731107761  14.195
# 1            2019  100248  731107761  14.155
# 2            2019  100248  731107761  14.314
# 3            2019  100253  731116755  93.569
# 4            2019  100253  731116755  14.218
# ...           ...     ...        ...     ...
# 586574       2019  100229  731089517  14.138
# 586575       2019  100229  731089517  14.195
# 586576       2019  100229  731089517  14.191
# 586577       2019  100236  731096719  10.558
# 586578       2019  100236  731096719  93.575
#
#                          AWARDIDENTIFICATION  RD  \
# 0                                        NaN NaN
# 1                                        NaN NaN
# 2                                        NaN NaN
# 3                                        NaN NaN
# 4                                        NaN NaN
# ...                                      ...  ..
# 586574  SECTION 223(F) INSURED MORTGAGE LOAN NaN
# 586575                                   NaN NaN
# 586576                                   NaN NaN
# 586577                                   NaN NaN
# 586578                                   NaN NaN
#
#                                        FEDERALPROGRAMNAME   AMOUNT  \
# 0           SECTION 8 HOUSING ASSISTANCE PAYMENTS PROGRAM   645955
# 1       MORTGAGE INSURANCE FOR THE PURCHASE OR REFINAN...  4502428
# 2       ASSISTED LIVING CONVERSION FOR ELIGIBLE MULTIF...  3877141
# 3                          COMMUNITY SERVICES BLOCK GRANT   163452
# 4       COMMUNITY DEVELOPMENT BLOCK GRANTS/ENTITLEMENT...    67020
# ...                                                   ...      ...
# 586574  MORTGAGE INSURANCE_RENTAL HOUSING FOR THE ELDERLY   526165
# 586575      SECTION 8 HOUSING ASSISTANCE PAYMENTS PROGRAM   568147
# 586576           MULTIFAMILY HOUSING SERVICE COORDINATORS    26840
# 586577                  CHILD AND ADULT CARE FOOD PROGRAM  1277958
# 586578             CHILD CARE AND DEVELOPMENT BLOCK GRANT   482278
#
#                             CLUSTERNAME STATECLUSTERNAME  ...  QCOSTS2  \
# 0                                   NaN              NaN  ...      NaN
# 1                                   NaN              NaN  ...      NaN
# 2                                   NaN              NaN  ...      NaN
# 3                                   NaN              NaN  ...      NaN
# 4                                   NaN              NaN  ...      NaN
# ...                                 ...              ...  ...      ...
# 586574                              NaN              NaN  ...      NaN
# 586575  SECTION 8 PROJECT-BASED CLUSTER              NaN  ...      NaN
# 586576                              NaN              NaN  ...      NaN
# 586577                              NaN              NaN  ...      NaN
# 586578                              NaN              NaN  ...      NaN
#
#         FINDINGS FINDINGREFNUMS ARRA  LOANS LOANBALANCE FINDINGSCOUNT  \
# 0            NaN            NaN  NaN      N         NaN           1.0
# 1            NaN            NaN  NaN      Y   4412263.0           0.0
# 2            NaN            NaN  NaN      Y   3877141.0           0.0
# 3            NaN            NaN  NaN      N         NaN           0.0
# 4            NaN            NaN  NaN      N         NaN           0.0
# ...          ...            ...  ...    ...         ...           ...
# 586574       NaN            NaN  NaN      Y    526165.0           0.0
# 586575       NaN            NaN  NaN      N         NaN           0.0
# 586576       NaN            NaN  NaN      N         NaN           0.0
# 586577       NaN            NaN  NaN      N         NaN           0.0
# 586578       NaN            NaN  NaN      N         NaN           0.0
#
#         ELECAUDITSID  OTHERCLUSTERNAME  \
# 0           30704169               NaN
# 1           30704170               NaN
# 2           30704171               NaN
# 3           31527652               NaN
# 4           31527663               NaN
# ...              ...               ...
# 586574      31073599               NaN
# 586575      31073709               NaN
# 586576      31073728               NaN
# 586577      31448252               NaN
# 586578      31448253               NaN
#
#                                           CFDAPROGRAMNAME
# 0           SECTION 8 HOUSING ASSISTANCE PAYMENTS PROGRAM
# 1       MORTGAGE INSURANCE FOR THE PURCHASE OR REFINAN...
# 2       ASSISTED LIVING CONVERSION FOR ELIGIBLE MULTIF...
# 3                          COMMUNITY SERVICES BLOCK GRANT
# 4       COMMUNITY DEVELOPMENT BLOCK GRANTS/ENTITLEMENT...
# ...                                                   ...
# 586574  MORTGAGE INSURANCE_RENTAL HOUSING FOR THE ELDERLY
# 586575      SECTION 8 HOUSING ASSISTANCE PAYMENTS PROGRAM
# 586576           MULTIFAMILY HOUSING SERVICE COORDINATORS
# 586577                  CHILD AND ADULT CARE FOOD PROGRAM
# 586578             CHILD CARE AND DEVELOPMENT BLOCK GRANT
#
# [586579 rows x 28 columns]
